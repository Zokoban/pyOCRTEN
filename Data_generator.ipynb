# %% [markdown]
# <a href="https://colab.research.google.com/github/Zokoban/pyOCRTEN/blob/Full_TensorFlow/Data_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To Do List :
#
# Modeling:
# *   Test other neural network structure (LSTM cell) (done)
# *   Change the neural network to line prediction instead of word prediction
#
# Pre_processing:
# *   Focus on the bad result and find some improvement solution :
# >1.   Use image_generation
# >2.   Implement Caracter Error Rate (CER)
# >3.   Check the symbols/characters which have the lowest prediction result and find solution (For example: generate more image related to these symbols)
#
# Model post_processing:
# *	Study the "greedy decoder" to improve the prediction choice at the end
#
# End result processing:
# *	Work on the Prediction end result to improve it through a new model such as:
# >1.	Orthographic model (done)
# >2.	NLP model
#
# General: (Progress)
# *	Improve the general aesthetic:
# >1.	Create pretty diagram
# >2.	Add more comments
# >3.	Add more "text" cell for explanation
# >4.	Improve the aesthetic of the titles, etc...
#
# Model application next steps: (done)
# *	Create our own segmentation method to directly perform prediction on the form image instead of using the images provided by the dataset.

# %%
#@title Download all data on the drive
# !wget -q https://git.io/J0fjL -O IAM_Words.zip
# !unzip -qq IAM_Words.zip
!
# !mkdir data
# !mkdir data/words
# !tar -xf IAM_Words/words.tgz -C data/words
# !mv IAM_Words/words.txt data

# %%
from google.colab import drive

drive.mount("/drive")
# Out:
# Mounted at /drive

# %%
# !cp /drive/MyDrive/DataScience/OCR/data/preprocess_image.zip ./preprocess_image.zip

# %%
# !unzip preprocess_image.zip -d preprocess_image
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: preprocess_image/preprocess_image/g07-065-03-03.png
#  extracting: preprocess_image/preprocess_image/g07-084-03-10.png
#  extracting: preprocess_image/preprocess_image/p02-109-07-07.png
#  extracting: preprocess_image/preprocess_image/a01-072x-00-05.png
#  extracting: preprocess_image/preprocess_image/r02-054-04-00.png
#  extracting: preprocess_image/preprocess_image/h07-007-05-04.png
#  extracting: preprocess_image/preprocess_image/g01-034-07-00.png
#  extracting: preprocess_image/preprocess_image/p02-069-05-06.png
#  extracting: preprocess_image/preprocess_image/a01-063x-00-03.png
#  extracting: preprocess_image/preprocess_image/m01-095-07-05.png
#  extracting: preprocess_image/preprocess_image/p02-109-03-04.png
#  extracting: preprocess_image/preprocess_image/d06-082-03-06.png
#  extracting: preprocess_image/preprocess_image/a02-027-05-01.png
#  extracting: preprocess_image/preprocess_image/c06-091-00-05.png
#  extracting: preprocess_image/preprocess_image/l04-113-02-12.png
#  extracting: preprocess_image/preprocess_image/c03-081d-03-02.png
#  extracting: preprocess_image/preprocess_image/l01-157-02-04.png
#  extracting: preprocess_image/preprocess_image/g06-047b-06-04.png
#  extracting: preprocess_image/preprocess_image/a06-000-07-04.png
#  extracting: preprocess_image/preprocess_image/p03-181-03-00.png
#  extracting: preprocess_image/preprocess_image/m03-110-01-02.png
#  extracting: preprocess_image/preprocess_image/b04-169-03-01.png
#  extracting: preprocess_image/preprocess_image/p02-139-03-01.png
#  extracting: preprocess_image/preprocess_image/g06-050i-02-00.png
#  extracting: preprocess_image/preprocess_image/k07-063a-06-05.png
#  extracting: preprocess_image/preprocess_image/c04-000-02-05.png
#  extracting: preprocess_image/preprocess_image/n03-079-02-03.png
#  extracting: preprocess_image/preprocess_image/g01-037-02-01.png
#  extracting: preprocess_image/preprocess_image/p02-090-06-00.png
#  extracting: preprocess_image/preprocess_image/g06-047i-02-05.png
#  extracting: preprocess_image/preprocess_image/b06-064-01-05.png
#  extracting: preprocess_image/preprocess_image/a04-050-00-06.png
#  extracting: preprocess_image/preprocess_image/g01-043-02-02.png
#  extracting: preprocess_image/preprocess_image/a01-102u-06-05.png
#  extracting: preprocess_image/preprocess_image/c06-047-00-08.png
#  extracting: preprocess_image/preprocess_image/n06-163-06-00.png
#  extracting: preprocess_image/preprocess_image/h04-082-06-05.png
#  extracting: preprocess_image/preprocess_image/h02-028-01-00.png
#  extracting: preprocess_image/preprocess_image/p02-101-06-02.png
#  extracting: preprocess_image/preprocess_image/c06-087-04-02.png
#  extracting: preprocess_image/preprocess_image/n03-091-03-11.png
#  extracting: preprocess_image/preprocess_image/g06-011h-09-08.png
#  extracting: preprocess_image/preprocess_image/f04-093-07-03.png
#  extracting: preprocess_image/preprocess_image/d07-089-02-02.png
#  extracting: preprocess_image/preprocess_image/c03-016a-01-02.png
#  extracting: preprocess_image/preprocess_image/f07-084a-00-07.png
#  extracting: preprocess_image/preprocess_image/g04-011-01-03.png
#  extracting: preprocess_image/preprocess_image/b04-208-01-04.png
#  extracting: preprocess_image/preprocess_image/b04-202-05-03.png
#  extracting: preprocess_image/preprocess_image/f07-009-06-01.png
#  extracting: preprocess_image/preprocess_image/e01-059-06-01.png
#  extracting: preprocess_image/preprocess_image/a01-049x-09-00.png
#  extracting: preprocess_image/preprocess_image/c02-003-04-03.png
#  extracting: preprocess_image/preprocess_image/j04-103-01-01.png
#  extracting: preprocess_image/preprocess_image/d06-107-07-04.png
#  extracting: preprocess_image/preprocess_image/a02-017-05-00.png
#  extracting: preprocess_image/preprocess_image/l04-159-08-06.png
#  extracting: preprocess_image/preprocess_image/g07-034-01-00.png
#  extracting: preprocess_image/preprocess_image/d04-037-02-05.png
#  extracting: preprocess_image/preprocess_image/c06-039-03-03.png
#  extracting: preprocess_image/preprocess_image/b01-004-05-04.png
#  extracting: preprocess_image/preprocess_image/c03-094c-01-02.png
#  extracting: preprocess_image/preprocess_image/c04-139-06-04.png
#  extracting: preprocess_image/preprocess_image/k07-077-05-13.png
#  extracting: preprocess_image/preprocess_image/h01-014-06-05.png
#  extracting: preprocess_image/preprocess_image/j04-053-00-02.png
#  extracting: preprocess_image/preprocess_image/r02-038-05-08.png
#  extracting: preprocess_image/preprocess_image/h07-028a-02-07.png
#  extracting: preprocess_image/preprocess_image/n04-044-07-06.png
#  extracting: preprocess_image/preprocess_image/c02-078-05-09.png
#  extracting: preprocess_image/preprocess_image/a03-037-05-06.png
#  extracting: preprocess_image/preprocess_image/c03-094f-08-05.png
#  extracting: preprocess_image/preprocess_image/p03-012-01-02.png
#  extracting: preprocess_image/preprocess_image/a06-100-05-00.png
#  extracting: preprocess_image/preprocess_image/a05-069-08-01.png
#  extracting: preprocess_image/preprocess_image/h06-082-01-01.png
#  extracting: preprocess_image/preprocess_image/m04-145-06-08.png
#  extracting: preprocess_image/preprocess_image/b05-032-01-03.png
#  extracting: preprocess_image/preprocess_image/n06-194-02-04.png
#  extracting: preprocess_image/preprocess_image/e06-041-02-02.png
#  extracting: preprocess_image/preprocess_image/g06-037p-01-10.png
#  extracting: preprocess_image/preprocess_image/k02-062-08-05.png
#  extracting: preprocess_image/preprocess_image/g06-031l-00-07.png
#  extracting: preprocess_image/preprocess_image/e01-050-05-07.png
#  extracting: preprocess_image/preprocess_image/n02-045-03-10.png
#  extracting: preprocess_image/preprocess_image/a06-147-03-08.png
#  extracting: preprocess_image/preprocess_image/m06-056-00-02.png
#  extracting: preprocess_image/preprocess_image/h07-060a-05-01.png
#  extracting: preprocess_image/preprocess_image/l01-111-03-08.png
#  extracting: preprocess_image/preprocess_image/e07-079-03-04.png
#  extracting: preprocess_image/preprocess_image/n02-000-05-05.png
#  extracting: preprocess_image/preprocess_image/h07-054a-01-00.png
#  extracting: preprocess_image/preprocess_image/e07-098-06-02.png
#  extracting: preprocess_image/preprocess_image/c03-016c-09-08.png
#  extracting: preprocess_image/preprocess_image/k07-134-03-07.png
#  extracting: preprocess_image/preprocess_image/f07-039b-03-03.png
#  extracting: preprocess_image/preprocess_image/h07-030a-00-02.png
#  extracting: preprocess_image/preprocess_image/b06-049-05-00.png
#  extracting: preprocess_image/preprocess_image/h06-079-03-01.png
#  extracting: preprocess_image/preprocess_image/m04-190-01-04.png
#  extracting: preprocess_image/preprocess_image/e04-114-07-00.png
#  extracting: preprocess_image/preprocess_image/a05-058-04-05.png
#  extracting: preprocess_image/preprocess_image/h07-069a-01-07.png
#  extracting: preprocess_image/preprocess_image/b04-107-07-03.png
#  extracting: preprocess_image/preprocess_image/n01-009-03-04.png
#   inflating: preprocess_image/preprocess_image/a05-069-09-00.png
#  extracting: preprocess_image/preprocess_image/b01-122-04-06.png
#  extracting: preprocess_image/preprocess_image/g01-083-09-10.png
#  extracting: preprocess_image/preprocess_image/g06-042l-04-03.png
#  extracting: preprocess_image/preprocess_image/a04-006-10-01.png
#  extracting: preprocess_image/preprocess_image/e04-011-02-01.png
#  extracting: preprocess_image/preprocess_image/e04-099-05-05.png
#  extracting: preprocess_image/preprocess_image/d06-003-00-04.png
#  extracting: preprocess_image/preprocess_image/a01-128u-03-04.png
#  extracting: preprocess_image/preprocess_image/m01-038-02-05.png
#  extracting: preprocess_image/preprocess_image/m03-095-04-02.png
#  extracting: preprocess_image/preprocess_image/b01-057-07-03.png
#  extracting: preprocess_image/preprocess_image/j06-000-00-07.png
#  extracting: preprocess_image/preprocess_image/g06-050b-01-05.png
#  extracting: preprocess_image/preprocess_image/c02-000-00-07.png
#  extracting: preprocess_image/preprocess_image/h07-025-08-01.png
#  extracting: preprocess_image/preprocess_image/a03-059-08-04.png
#  extracting: preprocess_image/preprocess_image/a01-117-08-03.png
#  extracting: preprocess_image/preprocess_image/n04-084-02-05.png
#  extracting: preprocess_image/preprocess_image/a01-038x-04-00.png
#  extracting: preprocess_image/preprocess_image/j04-070-04-04.png
#  extracting: preprocess_image/preprocess_image/e04-119-01-03.png
#  extracting: preprocess_image/preprocess_image/a01-091-05-00.png
#  extracting: preprocess_image/preprocess_image/g06-018p-02-07.png
#  extracting: preprocess_image/preprocess_image/g06-042d-01-01.png
#  extracting: preprocess_image/preprocess_image/p06-042-00-05.png
#  extracting: preprocess_image/preprocess_image/r02-070-00-08.png
#  extracting: preprocess_image/preprocess_image/g06-037m-02-06.png
#  extracting: preprocess_image/preprocess_image/c03-016b-01-08.png
#  extracting: preprocess_image/preprocess_image/g07-084-03-01.png
#  extracting: preprocess_image/preprocess_image/a03-017-05-00.png
#  extracting: preprocess_image/preprocess_image/c04-004-03-01.png
#  extracting: preprocess_image/preprocess_image/a01-003u-00-04.png
#  extracting: preprocess_image/preprocess_image/c06-058-06-08.png
#  extracting: preprocess_image/preprocess_image/j04-008-06-05.png
#  extracting: preprocess_image/preprocess_image/a05-039-06-05.png
#  extracting: preprocess_image/preprocess_image/a06-044-03-07.png
#  extracting: preprocess_image/preprocess_image/g01-067-04-08.png
#  extracting: preprocess_image/preprocess_image/g01-025-05-01.png
#  extracting: preprocess_image/preprocess_image/h07-051b-03-00.png
#  extracting: preprocess_image/preprocess_image/g06-047b-00-00.png
#  extracting: preprocess_image/preprocess_image/m04-038-03-07.png
#  extracting: preprocess_image/preprocess_image/h06-089-03-07.png
#  extracting: preprocess_image/preprocess_image/a01-007x-00-04.png
#  extracting: preprocess_image/preprocess_image/g04-104-01-04.png
#  extracting: preprocess_image/preprocess_image/g06-045i-05-09.png
#  extracting: preprocess_image/preprocess_image/h07-066a-03-03.png
#  extracting: preprocess_image/preprocess_image/f04-087-00-03.png
#  extracting: preprocess_image/preprocess_image/g06-047i-04-04.png
#  extracting: preprocess_image/preprocess_image/f04-049-06-01.png
#  extracting: preprocess_image/preprocess_image/g06-037f-07-07.png
#  extracting: preprocess_image/preprocess_image/c03-007f-07-08.png
#  extracting: preprocess_image/preprocess_image/k03-157-01-04.png
#  extracting: preprocess_image/preprocess_image/g06-037e-03-06.png
#  extracting: preprocess_image/preprocess_image/l04-005-06-08.png
#  extracting: preprocess_image/preprocess_image/n02-028-06-01.png
#  extracting: preprocess_image/preprocess_image/h02-049-05-02.png
#  extracting: preprocess_image/preprocess_image/c02-030-02-10.png
#  extracting: preprocess_image/preprocess_image/d04-053-07-07.png
#  extracting: preprocess_image/preprocess_image/p01-155-01-04.png
#  extracting: preprocess_image/preprocess_image/g06-037h-06-00.png
#  extracting: preprocess_image/preprocess_image/f07-069-02-07.png
#  extracting: preprocess_image/preprocess_image/p02-144-06-04.png
#  extracting: preprocess_image/preprocess_image/a04-092-00-03.png
#  extracting: preprocess_image/preprocess_image/c03-021a-00-01.png
#  extracting: preprocess_image/preprocess_image/c03-007e-08-03.png
#  extracting: preprocess_image/preprocess_image/k04-028-05-07.png
#  extracting: preprocess_image/preprocess_image/f04-057-04-08.png
#  extracting: preprocess_image/preprocess_image/b05-062-03-10.png
#  extracting: preprocess_image/preprocess_image/e01-092-01-01.png
#  extracting: preprocess_image/preprocess_image/a01-053-03-02.png
#  extracting: preprocess_image/preprocess_image/m01-131-00-01.png
#  extracting: preprocess_image/preprocess_image/l04-147-00-04.png
#  extracting: preprocess_image/preprocess_image/f07-081a-03-04.png
#  extracting: preprocess_image/preprocess_image/e04-058-00-01.png
#  extracting: preprocess_image/preprocess_image/a05-013-06-04.png
#  extracting: preprocess_image/preprocess_image/b04-004-01-00.png
#  extracting: preprocess_image/preprocess_image/d07-082-06-06.png
#  extracting: preprocess_image/preprocess_image/k04-033-05-06.png
#  extracting: preprocess_image/preprocess_image/n01-031-02-07.png
#  extracting: preprocess_image/preprocess_image/f07-092a-02-01.png
#  extracting: preprocess_image/preprocess_image/e01-055-03-03.png
#  extracting: preprocess_image/preprocess_image/p02-105-06-04.png
#  extracting: preprocess_image/preprocess_image/h01-030-08-02.png
#  extracting: preprocess_image/preprocess_image/g06-042j-00-04.png
#  extracting: preprocess_image/preprocess_image/g06-037c-07-00.png
#  extracting: preprocess_image/preprocess_image/a02-102-05-01.png
#  extracting: preprocess_image/preprocess_image/g06-011n-00-06.png
#  extracting: preprocess_image/preprocess_image/f04-071-03-04.png
#  extracting: preprocess_image/preprocess_image/k07-176-04-05.png
#  extracting: preprocess_image/preprocess_image/r03-030-03-00.png
#  extracting: preprocess_image/preprocess_image/a03-006-00-09.png
#  extracting: preprocess_image/preprocess_image/g06-050e-01-12.png
#  extracting: preprocess_image/preprocess_image/l07-111-02-03.png
#  extracting: preprocess_image/preprocess_image/b01-118-06-02.png
#  extracting: preprocess_image/preprocess_image/l04-071-06-07.png
#  extracting: preprocess_image/preprocess_image/e07-105-04-04.png
#  extracting: preprocess_image/preprocess_image/a01-132-08-01.png
#  extracting: preprocess_image/preprocess_image/b06-042-07-07.png
#  extracting: preprocess_image/preprocess_image/g07-026b-07-06.png
#  extracting: preprocess_image/preprocess_image/c03-007-03-03.png
#  extracting: preprocess_image/preprocess_image/n02-109-00-06.png
#  extracting: preprocess_image/preprocess_image/c04-116-02-14.png
#  extracting: preprocess_image/preprocess_image/l01-195-07-03.png
#  extracting: preprocess_image/preprocess_image/g06-045f-00-08.png
#  extracting: preprocess_image/preprocess_image/f07-002-06-06.png
#  extracting: preprocess_image/preprocess_image/a04-039-08-03.png
#  extracting: preprocess_image/preprocess_image/c06-128-07-02.png
#  extracting: preprocess_image/preprocess_image/f04-043-02-07.png
#  extracting: preprocess_image/preprocess_image/g03-052-10-04.png
#  extracting: preprocess_image/preprocess_image/a06-095-08-01.png
#  extracting: preprocess_image/preprocess_image/m01-090-05-00.png
#  extracting: preprocess_image/preprocess_image/g06-042b-02-06.png
#  extracting: preprocess_image/preprocess_image/e01-029-00-08.png
#  extracting: preprocess_image/preprocess_image/m01-038-08-01.png
#  extracting: preprocess_image/preprocess_image/k07-152-04-00.png
#  extracting: preprocess_image/preprocess_image/d07-093-00-01.png
#  extracting: preprocess_image/preprocess_image/e01-113-01-04.png
#  extracting: preprocess_image/preprocess_image/k02-029-04-01.png
#  extracting: preprocess_image/preprocess_image/d04-047-07-05.png
#  extracting: preprocess_image/preprocess_image/p03-040-02-04.png
#  extracting: preprocess_image/preprocess_image/a06-008-02-02.png
#  extracting: preprocess_image/preprocess_image/l07-103-05-01.png
#  extracting: preprocess_image/preprocess_image/g06-050k-08-09.png
#  extracting: preprocess_image/preprocess_image/c02-012-06-03.png
#  extracting: preprocess_image/preprocess_image/g06-042p-01-00.png
#  extracting: preprocess_image/preprocess_image/r06-007-07-01.png
#  extracting: preprocess_image/preprocess_image/h07-071-08-03.png
#  extracting: preprocess_image/preprocess_image/m04-238-02-03.png
#  extracting: preprocess_image/preprocess_image/b06-064-02-01.png
#  extracting: preprocess_image/preprocess_image/e01-081-02-07.png
#  extracting: preprocess_image/preprocess_image/g06-026c-00-11.png
#  extracting: preprocess_image/preprocess_image/p01-174-06-07.png
#  extracting: preprocess_image/preprocess_image/h06-000-06-00.png
#  extracting: preprocess_image/preprocess_image/k02-018-06-02.png
#  extracting: preprocess_image/preprocess_image/p02-022-08-00.png
#  extracting: preprocess_image/preprocess_image/j06-005-07-05.png
#  extracting: preprocess_image/preprocess_image/h04-057-02-07.png
#  extracting: preprocess_image/preprocess_image/c03-016c-08-02.png
#  extracting: preprocess_image/preprocess_image/n06-175-05-05.png
#  extracting: preprocess_image/preprocess_image/d01-104-02-01.png
#  extracting: preprocess_image/preprocess_image/a01-053-02-04.png
#  extracting: preprocess_image/preprocess_image/g06-018l-01-06.png
#  extracting: preprocess_image/preprocess_image/a06-141-06-03.png
#  extracting: preprocess_image/preprocess_image/b01-018-01-05.png
#  extracting: preprocess_image/preprocess_image/p02-022-00-01.png
#  extracting: preprocess_image/preprocess_image/e02-021-00-00.png
#  extracting: preprocess_image/preprocess_image/e07-098-06-06.png
#  extracting: preprocess_image/preprocess_image/n02-033-05-03.png
#  extracting: preprocess_image/preprocess_image/l04-179-06-01.png
#  extracting: preprocess_image/preprocess_image/j04-039-06-09.png
#  extracting: preprocess_image/preprocess_image/m04-251-00-01.png
#  extracting: preprocess_image/preprocess_image/g06-011c-07-03.png
#  extracting: preprocess_image/preprocess_image/c03-021b-00-02.png
#  extracting: preprocess_image/preprocess_image/m02-083-03-09.png
#  extracting: preprocess_image/preprocess_image/m02-090-07-02.png
#  extracting: preprocess_image/preprocess_image/p02-027-02-14.png
#  extracting: preprocess_image/preprocess_image/j06-051-08-00.png
#  extracting: preprocess_image/preprocess_image/d01-056-08-01.png
#  extracting: preprocess_image/preprocess_image/p03-012-07-01.png
#  extracting: preprocess_image/preprocess_image/g06-045p-02-02.png
#  extracting: preprocess_image/preprocess_image/n03-106-07-02.png
#  extracting: preprocess_image/preprocess_image/c03-081b-01-01.png
#  extracting: preprocess_image/preprocess_image/n06-119-01-04.png
#  extracting: preprocess_image/preprocess_image/c03-096f-03-03.png
#  extracting: preprocess_image/preprocess_image/f07-002-05-02.png
#  extracting: preprocess_image/preprocess_image/g03-032-06-03.png
#  extracting: preprocess_image/preprocess_image/h01-014-07-08.png
#  extracting: preprocess_image/preprocess_image/g07-003a-07-00.png
#  extracting: preprocess_image/preprocess_image/p02-000-01-01.png
#  extracting: preprocess_image/preprocess_image/n02-045-00-09.png
#  extracting: preprocess_image/preprocess_image/c03-007c-07-05.png
#  extracting: preprocess_image/preprocess_image/b06-064-08-00.png
#  extracting: preprocess_image/preprocess_image/l01-187-04-03.png
#  extracting: preprocess_image/preprocess_image/g04-043-02-03.png
#  extracting: preprocess_image/preprocess_image/a01-072u-00-04.png
#  extracting: preprocess_image/preprocess_image/p02-076-06-03.png
#  extracting: preprocess_image/preprocess_image/j04-094-03-05.png
#  extracting: preprocess_image/preprocess_image/g07-000a-09-00.png
#  extracting: preprocess_image/preprocess_image/k07-152-01-03.png
#  extracting: preprocess_image/preprocess_image/r03-007-03-06.png
#  extracting: preprocess_image/preprocess_image/g06-031b-08-08.png
#  extracting: preprocess_image/preprocess_image/b04-010-00-04.png
#  extracting: preprocess_image/preprocess_image/k04-017-05-07.png
#  extracting: preprocess_image/preprocess_image/g06-050b-04-01.png
#  extracting: preprocess_image/preprocess_image/f07-081a-01-00.png
#  extracting: preprocess_image/preprocess_image/g06-026e-05-00.png
#  extracting: preprocess_image/preprocess_image/n02-040-03-02.png
#  extracting: preprocess_image/preprocess_image/a01-107u-05-03.png
#  extracting: preprocess_image/preprocess_image/g06-037e-02-05.png
#  extracting: preprocess_image/preprocess_image/j01-066-10-05.png
#  extracting: preprocess_image/preprocess_image/l07-065-02-09.png
#  extracting: preprocess_image/preprocess_image/g06-011l-01-03.png
#  extracting: preprocess_image/preprocess_image/r03-050-06-07.png
#  extracting: preprocess_image/preprocess_image/g04-052-03-00.png
#  extracting: preprocess_image/preprocess_image/g07-044-09-06.png
#  extracting: preprocess_image/preprocess_image/b04-075-00-02.png
#  extracting: preprocess_image/preprocess_image/c06-095-02-00.png
#  extracting: preprocess_image/preprocess_image/g04-011-03-08.png
#  extracting: preprocess_image/preprocess_image/g06-042r-00-09.png
#  extracting: preprocess_image/preprocess_image/c06-076-00-03.png
#  extracting: preprocess_image/preprocess_image/g06-045p-03-07.png
#  extracting: preprocess_image/preprocess_image/a02-093-05-06.png
#  extracting: preprocess_image/preprocess_image/e07-108-06-01.png
#  extracting: preprocess_image/preprocess_image/h02-017-02-01.png
#  extracting: preprocess_image/preprocess_image/p02-022-03-02.png
#  extracting: preprocess_image/preprocess_image/g06-042p-00-10.png
#  extracting: preprocess_image/preprocess_image/h07-028-07-04.png
#  extracting: preprocess_image/preprocess_image/g01-043-09-00.png
#  extracting: preprocess_image/preprocess_image/l04-005-04-03.png
#  extracting: preprocess_image/preprocess_image/f04-083-01-04.png
#  extracting: preprocess_image/preprocess_image/c03-096c-04-08.png
#  extracting: preprocess_image/preprocess_image/j04-019-02-01.png
#  extracting: preprocess_image/preprocess_image/h07-011-01-08.png
#  extracting: preprocess_image/preprocess_image/b04-066-00-06.png
#  extracting: preprocess_image/preprocess_image/g06-037h-02-02.png
#  extracting: preprocess_image/preprocess_image/n04-015-05-01.png
#  extracting: preprocess_image/preprocess_image/d01-098-03-06.png
#  extracting: preprocess_image/preprocess_image/f07-006-02-03.png
#  extracting: preprocess_image/preprocess_image/g06-011o-04-07.png
#  extracting: preprocess_image/preprocess_image/c06-047-02-02.png
#  extracting: preprocess_image/preprocess_image/d06-111-04-09.png
#  extracting: preprocess_image/preprocess_image/c04-122-07-05.png
#  extracting: preprocess_image/preprocess_image/a02-017-04-03.png
#  extracting: preprocess_image/preprocess_image/l04-071-02-02.png
#  extracting: preprocess_image/preprocess_image/c03-007f-04-05.png
#  extracting: preprocess_image/preprocess_image/d06-082-00-12.png
#  extracting: preprocess_image/preprocess_image/h01-030-00-03.png
#  extracting: preprocess_image/preprocess_image/l04-136-04-08.png
#  extracting: preprocess_image/preprocess_image/p03-135-01-01.png
#  extracting: preprocess_image/preprocess_image/h01-004-03-06.png
#  extracting: preprocess_image/preprocess_image/h07-037-05-02.png
#  extracting: preprocess_image/preprocess_image/g06-037c-01-02.png
#  extracting: preprocess_image/preprocess_image/g06-026b-05-00.png
#  extracting: preprocess_image/preprocess_image/g06-045b-00-02.png
#  extracting: preprocess_image/preprocess_image/f07-076a-04-03.png
#  extracting: preprocess_image/preprocess_image/h04-082-08-10.png
#  extracting: preprocess_image/preprocess_image/n03-126-03-04.png
#  extracting: preprocess_image/preprocess_image/g06-018k-03-02.png
#  extracting: preprocess_image/preprocess_image/a06-070-07-05.png
#  extracting: preprocess_image/preprocess_image/m01-121-05-07.png
#  extracting: preprocess_image/preprocess_image/g06-026o-06-02.png
#  extracting: preprocess_image/preprocess_image/a01-102u-05-03.png
#  extracting: preprocess_image/preprocess_image/b06-004-04-01.png
#  extracting: preprocess_image/preprocess_image/g07-047-10-03.png
#  extracting: preprocess_image/preprocess_image/r06-111-05-00.png
#  extracting: preprocess_image/preprocess_image/a05-058-05-03.png
#  extracting: preprocess_image/preprocess_image/r03-035-03-05.png
#  extracting: preprocess_image/preprocess_image/k04-079-07-00.png
#  extracting: preprocess_image/preprocess_image/a05-004-00-01.png
#  extracting: preprocess_image/preprocess_image/a06-095-06-01.png
#  extracting: preprocess_image/preprocess_image/h07-057a-04-08.png
#  extracting: preprocess_image/preprocess_image/g06-045p-02-08.png
#  extracting: preprocess_image/preprocess_image/g06-047o-02-08.png
#  extracting: preprocess_image/preprocess_image/p03-096-07-03.png
#  extracting: preprocess_image/preprocess_image/e07-072-06-08.png
#  extracting: preprocess_image/preprocess_image/r06-062-06-05.png
#  extracting: preprocess_image/preprocess_image/c02-056-03-10.png
#  extracting: preprocess_image/preprocess_image/e06-026-08-02.png
#  extracting: preprocess_image/preprocess_image/a05-094-06-02.png
#  extracting: preprocess_image/preprocess_image/c01-014-01-00.png
#  extracting: preprocess_image/preprocess_image/l01-000-07-00.png
#  extracting: preprocess_image/preprocess_image/f07-016-06-02.png
#  extracting: preprocess_image/preprocess_image/b06-015-06-01.png
#  extracting: preprocess_image/preprocess_image/m01-104-03-10.png
#  extracting: preprocess_image/preprocess_image/b06-064-01-01.png
#  extracting: preprocess_image/preprocess_image/c03-087a-05-01.png
#  extracting: preprocess_image/preprocess_image/c03-007c-01-01.png
#  extracting: preprocess_image/preprocess_image/m06-106-09-00.png
#  extracting: preprocess_image/preprocess_image/e07-007-04-05.png
#  extracting: preprocess_image/preprocess_image/c06-087-03-03.png
#  extracting: preprocess_image/preprocess_image/f04-061-01-02.png
#  extracting: preprocess_image/preprocess_image/n06-074-06-00.png
#  extracting: preprocess_image/preprocess_image/g06-031k-00-07.png
#  extracting: preprocess_image/preprocess_image/g06-026e-02-07.png
#  extracting: preprocess_image/preprocess_image/f01-053-07-03.png
#  extracting: preprocess_image/preprocess_image/d04-101-00-00.png
#  extracting: preprocess_image/preprocess_image/g06-018h-02-04.png
#  extracting: preprocess_image/preprocess_image/a01-030u-03-05.png
#  extracting: preprocess_image/preprocess_image/c06-011-08-00.png
#  extracting: preprocess_image/preprocess_image/d01-085-04-04.png
#  extracting: preprocess_image/preprocess_image/l01-157-03-01.png
#  extracting: preprocess_image/preprocess_image/e02-082-06-03.png
#  extracting: preprocess_image/preprocess_image/b05-058-00-11.png
#  extracting: preprocess_image/preprocess_image/g06-050k-02-01.png
#  extracting: preprocess_image/preprocess_image/c06-000-05-02.png
#  extracting: preprocess_image/preprocess_image/m04-152-04-00.png
#  extracting: preprocess_image/preprocess_image/f01-139-04-02.png
#  extracting: preprocess_image/preprocess_image/c03-094b-02-08.png
#  extracting: preprocess_image/preprocess_image/n01-036-05-00.png
#  extracting: preprocess_image/preprocess_image/m04-081-07-08.png
#  extracting: preprocess_image/preprocess_image/c04-017-00-02.png
#  extracting: preprocess_image/preprocess_image/r06-011-01-07.png
#  extracting: preprocess_image/preprocess_image/g04-043-04-04.png
#  extracting: preprocess_image/preprocess_image/n04-213-05-06.png
#  extracting: preprocess_image/preprocess_image/g01-070-03-09.png
#  extracting: preprocess_image/preprocess_image/b06-079-08-02.png
#  extracting: preprocess_image/preprocess_image/m04-164-01-02.png
#  extracting: preprocess_image/preprocess_image/h06-003-10-00.png
#  extracting: preprocess_image/preprocess_image/g06-037h-10-09.png
#  extracting: preprocess_image/preprocess_image/h07-071a-07-06.png
#  extracting: preprocess_image/preprocess_image/d01-052-06-06.png
#  extracting: preprocess_image/preprocess_image/m01-149-01-14.png
#  extracting: preprocess_image/preprocess_image/g06-047e-00-03.png
#  extracting: preprocess_image/preprocess_image/e04-079-03-04.png
#  extracting: preprocess_image/preprocess_image/p01-174-06-03.png
#  extracting: preprocess_image/preprocess_image/a02-057-07-03.png
#  extracting: preprocess_image/preprocess_image/a06-119-02-06.png
#  extracting: preprocess_image/preprocess_image/g03-052-05-05.png
#  extracting: preprocess_image/preprocess_image/b04-075-03-03.png
#  extracting: preprocess_image/preprocess_image/a05-004-00-03.png
#  extracting: preprocess_image/preprocess_image/c03-003d-03-08.png
#  extracting: preprocess_image/preprocess_image/k04-010-05-08.png
#  extracting: preprocess_image/preprocess_image/n04-084-04-04.png
#  extracting: preprocess_image/preprocess_image/g06-018k-01-01.png
#  extracting: preprocess_image/preprocess_image/b05-098-00-08.png
#  extracting: preprocess_image/preprocess_image/a01-117u-05-04.png
#  extracting: preprocess_image/preprocess_image/c03-007e-06-01.png
#  extracting: preprocess_image/preprocess_image/b04-026-06-04.png
#  extracting: preprocess_image/preprocess_image/b04-154-07-02.png
#  extracting: preprocess_image/preprocess_image/d01-080-05-01.png
#  extracting: preprocess_image/preprocess_image/h07-066a-03-01.png
#  extracting: preprocess_image/preprocess_image/l04-087-03-10.png
#  extracting: preprocess_image/preprocess_image/a04-019-01-03.png
#  extracting: preprocess_image/preprocess_image/l01-179-07-02.png
#  extracting: preprocess_image/preprocess_image/a03-009-02-05.png
#  extracting: preprocess_image/preprocess_image/f07-092a-01-05.png
#  extracting: preprocess_image/preprocess_image/h07-060a-04-05.png
#  extracting: preprocess_image/preprocess_image/d04-117-05-02.png
#  extracting: preprocess_image/preprocess_image/c04-139-01-14.png
#  extracting: preprocess_image/preprocess_image/c04-116-02-21.png
#  extracting: preprocess_image/preprocess_image/m06-042-04-05.png
#  extracting: preprocess_image/preprocess_image/f04-093-01-04.png
#  extracting: preprocess_image/preprocess_image/g07-047-07-00.png
#  extracting: preprocess_image/preprocess_image/g06-050o-04-06.png
#  extracting: preprocess_image/preprocess_image/g06-047p-05-00.png
#  extracting: preprocess_image/preprocess_image/p02-135-07-04.png
#  extracting: preprocess_image/preprocess_image/l04-159-02-01.png
#  extracting: preprocess_image/preprocess_image/l04-124-03-04.png
#  extracting: preprocess_image/preprocess_image/e07-076-02-07.png
#  extracting: preprocess_image/preprocess_image/m04-113-04-05.png
#  extracting: preprocess_image/preprocess_image/a04-010-06-02.png
#  extracting: preprocess_image/preprocess_image/c03-007e-04-00.png
#  extracting: preprocess_image/preprocess_image/r06-011-00-10.png
#  extracting: preprocess_image/preprocess_image/f07-021a-02-04.png
#  extracting: preprocess_image/preprocess_image/b03-098-06-02.png
#  extracting: preprocess_image/preprocess_image/p03-112-04-11.png
#  extracting: preprocess_image/preprocess_image/b06-097-07-06.png
#  extracting: preprocess_image/preprocess_image/e04-091-03-03.png
#  extracting: preprocess_image/preprocess_image/e02-094-09-02.png
#  extracting: preprocess_image/preprocess_image/n04-000-00-03.png
#  extracting: preprocess_image/preprocess_image/n02-045-04-08.png
#  extracting: preprocess_image/preprocess_image/p03-189-01-00.png
#  extracting: preprocess_image/preprocess_image/c03-003d-04-05.png
#  extracting: preprocess_image/preprocess_image/g05-087-02-04.png
#  extracting: preprocess_image/preprocess_image/e06-021-01-03.png
#  extracting: preprocess_image/preprocess_image/e04-062-07-03.png
#  extracting: preprocess_image/preprocess_image/g06-031p-03-05.png
#  extracting: preprocess_image/preprocess_image/f07-024b-02-06.png
#  extracting: preprocess_image/preprocess_image/g01-016-03-00.png
#  extracting: preprocess_image/preprocess_image/b05-071-02-03.png
#  extracting: preprocess_image/preprocess_image/m01-032-05-08.png
# ...
#  extracting: preprocess_image/preprocess_image/b05-032-03-02.png
#  extracting: preprocess_image/preprocess_image/g04-063-07-06.png
#  extracting: preprocess_image/preprocess_image/m02-052-05-09.png
#  extracting: preprocess_image/preprocess_image/r06-057-02-09.png
#  extracting: preprocess_image/preprocess_image/e06-041-09-01.png
#  extracting: preprocess_image/preprocess_image/a01-077-08-03.png
#  extracting: preprocess_image/preprocess_image/a01-020u-08-00.png
#  extracting: preprocess_image/preprocess_image/g06-011f-00-08.png
#   inflating: preprocess_image/preprocess_image/k04-085-07-05.png
#  extracting: preprocess_image/preprocess_image/a06-039-01-00.png
#  extracting: preprocess_image/preprocess_image/h06-085-02-02.png
#  extracting: preprocess_image/preprocess_image/r06-076-04-03.png
#  extracting: preprocess_image/preprocess_image/e06-046-03-07.png
#  extracting: preprocess_image/preprocess_image/k02-018-03-02.png
#  extracting: preprocess_image/preprocess_image/b01-009-02-03.png
#  extracting: preprocess_image/preprocess_image/b05-083-01-08.png
#  extracting: preprocess_image/preprocess_image/h07-063b-00-06.png
#  extracting: preprocess_image/preprocess_image/p03-012-07-02.png
#  extracting: preprocess_image/preprocess_image/g03-064-07-01.png
#  extracting: preprocess_image/preprocess_image/p03-072-04-03.png
#  extracting: preprocess_image/preprocess_image/c03-000e-04-06.png
#  extracting: preprocess_image/preprocess_image/m04-222-01-06.png
#  extracting: preprocess_image/preprocess_image/m02-072-03-09.png
#  extracting: preprocess_image/preprocess_image/d06-100-01-06.png
#  extracting: preprocess_image/preprocess_image/g06-018r-04-03.png
#  extracting: preprocess_image/preprocess_image/g06-018r-01-04.png
#  extracting: preprocess_image/preprocess_image/g06-031i-03-03.png
#  extracting: preprocess_image/preprocess_image/r02-013-04-02.png
#  extracting: preprocess_image/preprocess_image/g06-018a-07-03.png
#  extracting: preprocess_image/preprocess_image/a01-068u-08-04.png
#  extracting: preprocess_image/preprocess_image/b04-096-02-01.png
#  extracting: preprocess_image/preprocess_image/n06-186-03-01.png
#  extracting: preprocess_image/preprocess_image/g06-031m-03-08.png
#  extracting: preprocess_image/preprocess_image/g07-069a-06-02.png
#  extracting: preprocess_image/preprocess_image/m04-107-02-05.png
#  extracting: preprocess_image/preprocess_image/g06-045o-03-05.png
#  extracting: preprocess_image/preprocess_image/l04-179-07-09.png
#  extracting: preprocess_image/preprocess_image/c06-031-06-05.png
#  extracting: preprocess_image/preprocess_image/g07-003a-00-07.png
#  extracting: preprocess_image/preprocess_image/b05-050-05-01.png
#  extracting: preprocess_image/preprocess_image/h07-011-00-05.png

# %%
#@title Load all the required packages
import pandas as pd
import numpy as np
import csv
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Data Preparation

# %%
#@title Load word.txt file
#############
# Variables #
#############

path_to_txt = "data/words.txt"

#--------------------------------------

#########################
# Function get_word_txt #
#########################

def get_word_txt(path_to_txt):
  word_txt=pd.read_csv(path_to_txt, 
                      sep=' ', 
                      names=["word_id","segmentation_result","gray_level","x","y","pxw","pxh","grammatical_tag","transcription_1","transcription_2","transcription_3"], 
                      quoting=csv.QUOTE_NONE, 
                      skiprows=18, 
                      on_bad_lines="warn")

  def f(x):
      if x == "nan":
          return ""
      else:
          return x
  word_txt["transcription"]=word_txt.transcription_1.astype("str")+\
                            word_txt.transcription_2.astype("str").apply(f)+\
                            word_txt.transcription_3.astype("str").apply(f)
  word_txt=word_txt.drop(columns=["transcription_1","transcription_2","transcription_3"])

  def f(x):
      return len(x)

  word_txt["number_components"]=word_txt.transcription.apply(f)

  

  return word_txt

#----------------------------------------------------------

word_txt = get_word_txt(path_to_txt)

print("word_txt Length: ",len(word_txt))
word_txt.head()
# Out:
# word_txt Length:  115320
#           word_id segmentation_result  gray_level     x    y  pxw  pxh  \
# 0  a01-000u-00-00                  ok         154   408  768   27   51
# 1  a01-000u-00-01                  ok         154   507  766  213   48
# 2  a01-000u-00-02                  ok         154   796  764   70   50
# 3  a01-000u-00-03                  ok         154   919  757  166   78
# 4  a01-000u-00-04                  ok         154  1185  754  126   61
#
#   grammatical_tag transcription  number_components
# 0              AT             A                  1
# 1              NN          MOVE                  4
# 2              TO            to                  2
# 3              VB          stop                  4
# 4             NPT           Mr.                  3

# %%
#@title Choice of the fraction of the dataset / Removal of Transcription error / Removal of unwanted column

#############
# Variables #
#############

fraction = 0.01
data_dir = "data/words/"
preprocess_dir="preprocess_image/preprocess_image/"
image_extensions = [".png"]  # add there all your images file extensions
img_type_accepted_by_tf = ["png"]

random_state = 4321

#--------------------------------------------------------------------------
from pathlib import Path
import imghdr

def img_path(word):
    path=data_dir+word.split("-")[0]+"/"+word.split("-")[0]+"-"+word.split("-")[1]+"/"+word+".png"
    
    return path

def removal_of_corrupt_image(df):
  index_to_drop=[]
  for filepath in Path(data_dir).rglob("*"):
      if filepath.suffix.lower() in image_extensions:
          img_type = imghdr.what(filepath)
          if img_type is None:
              index_to_drop.append(df[df.filepath==str(filepath)].index)
              df=df.drop(labels=df[df.filepath==str(filepath)].index)
              print(f"{filepath} is not an image")
          elif img_type not in img_type_accepted_by_tf:
              df=df.drop(labels=df[df.filepath==str(filepath)].index)
              print(f"{filepath} is a {img_type}, not accepted by TensorFlow and is drop")
  return df

def word_txt_cleaning(word_txt,fraction,random_state=None):

  if random_state==None:
    random_state=np.random.randint(10000)

  list_columns_to_remove=["segmentation_result","gray_level","x","y","pxw","pxh","grammatical_tag","number_components"]

  df = word_txt[word_txt.segmentation_result == "ok"]\
      .drop(columns=list_columns_to_remove)\
      .sample(frac=fraction,random_state=random_state)

  df["filepath"]=df.word_id.apply(img_path)
  df["preprocess_filepath"]=df.word_id.apply(lambda x : preprocess_dir+x+".png")
  df=removal_of_corrupt_image(df)

  return df

#------------------------------------------------------------------

##################################
#   Removal of unwanted Column   #
#   And removal of corrupt image #
##################################


df = word_txt_cleaning(word_txt,fraction,random_state)

df.head()
# Out:
# data/words/a01/a01-117/a01-117-05-02.png is not an image
# data/words/r06/r06-022/r06-022-03-05.png is not an image
#                word_id transcription  \
# 58546   g06-011o-03-13             ,
# 79980    j04-111-07-02             .
# 95482    m04-019-02-11            is
# 111838   r02-127-01-03           who
# 62790   g06-031r-05-04   dissolution
#
#                                           filepath  \
# 58546   data/words/g06/g06-011o/g06-011o-03-13.png
# 79980     data/words/j04/j04-111/j04-111-07-02.png
# 95482     data/words/m04/m04-019/m04-019-02-11.png
# 111838    data/words/r02/r02-127/r02-127-01-03.png
# 62790   data/words/g06/g06-031r/g06-031r-05-04.png
#
#                                       preprocess_filepath
# 58546   preprocess_image/preprocess_image/g06-011o-03-...
# 79980   preprocess_image/preprocess_image/j04-111-07-0...
# 95482   preprocess_image/preprocess_image/m04-019-02-1...
# 111838  preprocess_image/preprocess_image/r02-127-01-0...
# 62790   preprocess_image/preprocess_image/g06-031r-05-...

# %% [markdown]
# ## Preaparation of dataset, Loading + Preprocessing of the image and Vectorization of the labels

# %%
#@title Loading and preprocessing of images

#############
# Variables #
#############

batch_size = 64
image_width=128
image_height=32
imgSize = (image_height, image_width)

random_state=np.random.randint(10000)
train_size=0.8
validation_size=0.5
#-----------------------------------

###############################################################
# Definition of functions:                                    #
#     - Loading images                                        #
#     - Preprocessing of images (resizing without distortion) #
###############################################################

import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np

#Loading function of images (with tensorflow)
@tf.function
def load_image(filepath):
    im = tf.io.read_file(filepath)
    im = tf.image.decode_png(im, channels=0)

    return im

#Preprocessing function of images (with tensorflow)
@tf.function
def preprocess(filepath, imgSize=(32, 128), dataAugmentation=False, scale=0.8, isthreshold=False):



    img = load_image(filepath)/255
    # there are damaged files in IAM dataset - just use black image instead
    if img is None:
        img = tf.ones([imgSize[0], imgSize[1], 1])
        print("None")

    if dataAugmentation:
        stretch = scale*(tf.random.uniform([1], 0, 1)[0] - 0.3) # -0.5 .. +0.5
        wStretched = tf.maximum(int(float(tf.shape(img)[0]) * (1 + stretch)), 1) # random width, but at least 1
        img = tf.image.resize(img, (wStretched, tf.shape(img)[1])) # stretch horizontally by factor 0.5 .. 1.5

    (wt, ht) = imgSize

    w, h = float(tf.shape(img)[0]), float(tf.shape(img)[1])

    fx = w / wt
    fy = h / ht

    f = tf.maximum(fx, fy)

    newSize = (tf.maximum(tf.minimum(wt, int(w / f)), 1), tf.maximum(tf.minimum(ht, int(h / f)), 1)) # scale according to f (result at least 1 and at most wt or ht)

    img = tf.image.resize(img, newSize)


    dx = wt - newSize[0]
    dy = ht - newSize[1]

    if dataAugmentation :
        dx1=0
        dy1=0
        if dx!=0:
            dx1 = tf.random.uniform([1], 0, dx, tf.int32)[0]
        if dy!=0:
            dy1 = tf.random.uniform([1], 0, dy, tf.int32)[0]
        img = tf.pad(img[..., 0], [[dx1, dx-dx1], [dy1, dy-dy1]], constant_values=0)
    else :
        img = tf.pad(img[..., 0], [[0, dx], [0, dy]], constant_values=0)

    if isthreshold:
        return tf.expand_dims(1-(1-img)*tf.cast(img < 0.8, tf.float32), -1)
    return tf.expand_dims(img, -1)

def create_dataset(X_path,y_label,batch_size):
  dataset = tf.data.Dataset.from_tensor_slices((X_path, y_label))
  dataset = dataset.shuffle(10000)\
                  .map(lambda x, y : [preprocess(x, imgSize, dataAugmentation=True, scale=0.8, isthreshold=True), y])\
                  .batch(batch_size, drop_remainder=True)
  return dataset
#-----------------------------------------------------------------------------

#########################################
# Creation of the train & test datasets #
#########################################

#Split of dataframes 
X_train_path, X_path_temp, y_train, y_temp = train_test_split(df.filepath.values, df.transcription.values, train_size=train_size, random_state=random_state)
X_test_path, X_val_path, y_test, y_val = train_test_split(X_path_temp, y_temp, train_size=validation_size, random_state=random_state)

# Creation of dataset_train and dataset_test tensor and preprocessing of images
dataset_train = create_dataset(X_train_path,y_train,batch_size)
dataset_test = create_dataset(X_test_path,y_test,batch_size)
dataset_validation = create_dataset(X_val_path,y_val,batch_size)

#-----------------------------------------------------------------------------

################################################
# Iteration on dataset_train                   #
# Display of several images from train dataset #
################################################

X_t, y_t = next(iter(dataset_train))

def display_image_from_tf_dataset(X_t,y_t):
  plt.figure(figsize=(15,5))
  for j, i in enumerate(np.random.randint(low=0, high=len(X_t), size=[6])):
      plt.subplot(2,3,j+1)
      plt.imshow(X_t[i][...,0], cmap='gray')
      plt.title(y_t[i].numpy().decode('utf'))

display_image_from_tf_dataset(X_t,y_t)

# %%
import tensorflow as tf

generator = tf.keras.preprocessing.image.ImageDataGenerator()

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self, df, X_col, y_col,
                 batch_size,
                 input_size=(224, 224, 3),
                 shuffle=True):
        
        self.df = df.copy()
        self.X_col = X_col
        self.y_col = y_col
        self.batch_size = batch_size
        self.input_size = input_size
        self.shuffle = shuffle
        
        self.n = len(self.df)

    
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __get_input(self, path, bbox, target_size):
    
        xmin, ymin, w, h = bbox['x'], bbox['y'], bbox['width'], bbox['height']

        image = tf.keras.preprocessing.image.load_img(path)
        image_arr = tf.keras.preprocessing.image.img_to_array(image)

        image_arr = image_arr[ymin:ymin+h, xmin:xmin+w]
        image_arr = tf.image.resize(image_arr,(target_size[0], target_size[1])).numpy()

        return image_arr/255.
    
    def __get_output(self, label, num_classes):
        return tf.keras.utils.to_categorical(label, num_classes=num_classes)
    
    def __get_data(self, batches):
        # Generates data containing batch_size samples

        image_path_batch = batches[self.X_col] 
         
        label_batch = batches[self.y_col] 

        
        dataset = tf.data.Dataset.from_tensor_slices((image_path_batch, label_batch))
        dataset = dataset.shuffle(10000)\
                        .map(lambda x, y : [preprocess(x, self.input_size, dataAugmentation=True, scale=0.8, isthreshold=True), y])\
                        .batch(self.batch_size, drop_remainder=True).map(lambda x,y : [x,encode_labels(y)])
        
        X_t,y_t = next(iter(dataset))

        return X_t,y_t
    
    def __getitem__(self, index):
        
        batches = self.df[index * self.batch_size:(index + 1) * self.batch_size]
        X, y = self.__get_data(batches)        
        return X, y
    
    def __len__(self):
        return self.n // self.batch_size

# %%
CustomDatagen = CustomDataGen(df,X_col="filepath",y_col="transcription",
                                  input_size=(32,128),
                                  batch_size=64)

# %%
X,y = CustomDatagen[0]

# %%
y

# %%
gen=generator.flow_from_dataframe(df,x_col="preprocess_filepath",y_col="transcription",
                                  target_size=imgSize,
                                  class_mode="raw",
                                  batch_size=32)
# Out:
# Found 96448 validated image filenames.

# %%
im, lab = gen.next()

# %%
im.shape
# Out:
# (32, 32, 128, 3)

# %%
plt.imshow(im[0].astype(np.uint8),cmap="gray")
plt.title(lab[0]);

# %%
lab[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
label = tf.data.Dataset.from_tensor_slices(df.transcription.values).batch(64).map(lambda y : encode_labels(y))

# %%
y_t = next(iter(label))

# %%
a = encode_labels(df.transcription.values)

# %%
tf.sparse.to_dense(a).numpy()
# Out:
# array([[12,  0,  0, ...,  0,  0,  0],
#        [14,  0,  0, ...,  0,  0,  0],
#        [73, 83,  0, ...,  0,  0,  0],
#        ...,
#        [70, 79, 82, ...,  0,  0,  0],
#        [12,  0,  0, ...,  0,  0,  0],
#        [84, 72, 69, ...,  0,  0,  0]], dtype=int32)

# %%
df["encode_val"]= pd.Dataframe(tf.sparse.to_dense(a).numpy())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-07cb6de8beef> in <module>
# ----> 1 df["encode_val"]= pd.Dataframe(tf.sparse.to_dense(a).numpy())
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-3d621880e9dc> in <module>
# ----> 1 pd.DataFrame(tf.sparse.to_dense(a).numpy(),axis=1)
#
# TypeError: __init__() got an unexpected keyword argument 'axis'

# %%
#@title Vectorization of the labels

#############
# Variables #
#############

import string
#charList = list(string.ascii_lowercase)
#charList = list('!\'.?abcdefghijklmnopqrstuvwxyz')
charList = list(' !"#$%&\'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~')
#------------------------------------------------

def encode_labels(labels):
    table = tf.lookup.StaticHashTable(
        tf.lookup.KeyValueTensorInitializer(charList, np.arange(len(charList)), value_dtype=tf.int32),
        default_value = 0,
        name='chard2id')
    return table.lookup(tf.compat.v1.string_split(labels, sep=''))


#--------------------------------------------------------------------

#######################################
# Encoding of the train & test labels #
#######################################

# Encoding of y_train
dataset_train = dataset_train.map(lambda X,y : [X, encode_labels(y)])

# Encode of y_test
dataset_validation = dataset_validation.map(lambda X,y : [X, encode_labels(y)])

#--------------------------------------------------------------------

##############################
# Display of label encoding  #
##############################

a = encode_labels(y_train[:10])

print(y_train[:10])
print(tf.sparse.to_dense(a).numpy(),":\n")

x=15
a = encode_labels(y_test[x:x+10])

print("\n-------------------------------------------\n\n",y_test[x:x+10],":\n")

print(tf.sparse.to_dense(a).numpy())

#------------------------------------------------------------------
# Out:
# ['We' 'ever' '.' 'and' 'perhaps' 'young' 'he' 'This' '.' '.']
# [[55 69  0  0  0  0  0]
#  [69 86 69 82  0  0  0]
#  [14  0  0  0  0  0  0]
#  [65 78 68  0  0  0  0]
#  [80 69 82 72 65 80 83]
#  [89 79 85 78 71  0  0]
#  [72 69  0  0  0  0  0]
#  [52 72 73 83  0  0  0]
#  [14  0  0  0  0  0  0]
#  [14  0  0  0  0  0  0]] :
#
#
# -------------------------------------------
#
#  ['unorthodox' 'Said' 'down' 'decided' 'of' 'Italy' 'some-' 'legality' ','
#  'her'] :
#
# [[85 78 79 82 84 72 79 68 79 88]
#  [51 65 73 68  0  0  0  0  0  0]
#  [68 79 87 78  0  0  0  0  0  0]
#  [68 69 67 73 68 69 68  0  0  0]
#  [79 70  0  0  0  0  0  0  0  0]
#  [41 84 65 76 89  0  0  0  0  0]
#  [83 79 77 69 13  0  0  0  0  0]
#  [76 69 71 65 76 73 84 89  0  0]
#  [12  0  0  0  0  0  0  0  0  0]
#  [72 69 82  0  0  0  0  0  0  0]]

# %%
X_t,y_t = next(iter(dataset_train))

# %%
y_t

# %%
y

# %% [markdown]
# #Model Creation

# %%
#@title Load weight model function (boolean, model, name_model)
import pickle

def load_weight_model(load_model,model,name):
  history=None
  #------------------------------
  if load_model: #Load model weights
    drive.mount("/drive",force_remount=True)
    try:
      model.load_weights("/drive/MyDrive/DataScience/OCR/Models/"+name)
      print("Model weights loaded !")
    except:
      print("Model name does not exist, Model weights not loaded !")
    #----------------------------
    try: #Load history
      with open("/drive/MyDrive/DataScience/OCR/Models/"+name+"training_history", "rb") as file_pi:
        history = pickle.load(file_pi)
        print("History loaded !")
    except Exception:
      print("History not loaded !")

  #--------------------------------
  else:
    print("Model weights not loaded !")

  return model,history

# %%
#@title Model_CRNN_GRU
#############
# Variables #
#############

#X_t.shape[1:]

#-------------------------------------------------------------------------
from google.colab import drive
#########################################################
# Definition of a model CRNN taken on DataScienTest OCR #
#                           model_CRNN_GRU              #
#########################################################

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, LeakyReLU, Dropout
from tensorflow.keras.layers import GRU, Bidirectional, Dense, Lambda


def build_model_CRNN_GRU(load_model_var, name_load_model, numHidden, image_shape):
    print("Building of Model: CRNN_GRU")
  #Create_model_CRNN
    model = tf.keras.Sequential()

    # Layer 1
    model.add(Conv2D(filters=32, kernel_size=(5,5), padding='SAME', input_shape = image_shape))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

    # Layer 2
    model.add(Conv2D(filters=64, kernel_size=(5,5), padding='SAME'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

    # Layer 3
    model.add(Conv2D(filters=128, kernel_size=(3,3), padding='SAME'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,1), strides=(2,1)))

    # Layer 4
    model.add(Conv2D(filters=128, kernel_size=(3,3), padding='SAME'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,1), strides=(2,1)))

    # Layer 5
    model.add(Conv2D(filters=256, kernel_size=(3,3), padding='SAME'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,1), strides=(2,1)))
    model.add(Dropout(0.4))


    model.add(Lambda(lambda x :tf.squeeze(x, axis=1)))

    # Bidirectionnal RNN
    model.add(Bidirectional(GRU(numHidden, return_sequences=True)))
    # Classification of characters
    model.add(Dense(len(charList)+1))
    
    model,training_history=load_weight_model(load_model_var,model,name_load_model)

    return model, training_history

#---------------------------------------------------------------------------

# %%
#@title Model_CRNN_LSTM
#############
# Variables #
#############

#X_t.shape[1:]

#-------------------------------------------------------------------------
from google.colab import drive
#########################################################
# Definition of a model CRNN taken on DataScienTest OCR #
#                           model_CRNN_GRU              #
#########################################################

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, LeakyReLU, Dropout
from tensorflow.keras.layers import GRU, Bidirectional, Dense, Lambda, LSTM


def build_model_CRNN_LSTM(load_model_var, name_load_model, numHidden, image_shape):
    print("Building of Model: CRNN_LSTM")
  #Create_model_CRNN
    model = tf.keras.Sequential()

    # Layer 1
    model.add(Conv2D(filters=32, kernel_size=(5,5), padding='SAME', input_shape = image_shape))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

    # Layer 2
    model.add(Conv2D(filters=64, kernel_size=(5,5), padding='SAME'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

    # Layer 3
    model.add(Conv2D(filters=128, kernel_size=(3,3), padding='SAME'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,1), strides=(2,1)))

    # Layer 4
    model.add(Conv2D(filters=128, kernel_size=(3,3), padding='SAME'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,1), strides=(2,1)))

    # Layer 5
    model.add(Conv2D(filters=256, kernel_size=(3,3), padding='SAME'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPooling2D(pool_size=(2,1), strides=(2,1)))
    model.add(Dropout(0.4))


    model.add(Lambda(lambda x :tf.squeeze(x, axis=1)))

    # Bidirectionnal RNN
    model.add(Bidirectional(LSTM(numHidden, return_sequences=True)))
    # Classification of characters
    model.add(Dense(len(charList)+1))
    
    model,training_history=load_weight_model(load_model_var,model,name_load_model)

    return model, training_history

#---------------------------------------------------------------------------

# %%
#@title Building of models
#############
# Variables #
#############
numHidden = 256

model_image_width=image_width 
model_image_height=image_height

image_shape=[model_image_height,model_image_width,1]

load_model_var_CNN_GRU = False
name_load_model_CNN_GRU = "CRNN_GRU"
#name_load_model_CNN = "CRNN_1_2710"

load_model_var_CNN_LSTM = True
name_load_model_CNN_LSTM = "CRNN_LSTM"

############################
# Building the model CRNN  #
#         model_3          #
############################


model_CRNN_GRU, training_history = build_model_CRNN_GRU(load_model_var_CNN_GRU, name_load_model_CNN_GRU, numHidden, image_shape)

model_CRNN_LSTM, training_history = build_model_CRNN_LSTM(load_model_var_CNN_LSTM, name_load_model_CNN_LSTM, numHidden, image_shape)


#model_CRNN_GRU.summary()
#

#--------------------------------------------------------------------------
# Out:
# Building of Model: CRNN_GRU
# Model weights not loaded !
# Building of Model: CRNN_LSTM
# Mounted at /drive
# Model weights loaded !
# History not loaded !

# %%
#@title Loss function and compilation of models

#############
# Variables #
#############

model_compiled = model_CRNN_GRU

#---------------------------------------

#########################################
# Definition of a loss function for CTC #
#########################################

#Loss function for CTC
def loss(labels, logits):
    return tf.reduce_mean(tf.nn.ctc_loss(
        labels = labels,
        logits = logits,
        logit_length = [logits.shape[1]]*logits.shape[0],
        label_length = None,
        logits_time_major = False,
        blank_index=-1))

#----------------------------------------------------------

######################################################
# Compilation of model_3 with Adam and Loss function #
######################################################
from tensorflow.keras.optimizers import Adam

model_CRNN_GRU.compile(optimizer=Adam(1e-3),loss=loss)
model_CRNN_LSTM.compile(optimizer=Adam(1e-3),loss=loss)
#------------------------------------------------------------

# %% [markdown]
# #Training

# %%
#@title save_model / callback function
import pickle
def save_model(save_model,model,name,training_history=None):
  drive.mount("/drive",force_remount=True)
  if save_model:
    model.save_weights("/drive/MyDrive/DataScience/OCR/Models/"+name)
    print("Model saved !")
    if training_history != None:
      with open("/drive/MyDrive/DataScience/OCR/Models/"+name+"_training_history", 'wb') as file_pi:
        pickle.dump(training_history.history, file_pi)
        print("History saved !")
  else:
    print("Model not saved !")

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.01,
    patience=5,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#@title Model training

#############
# Variables #
#############

save_model_bol=True # True or False for saving
epochs = 50 # Number of epochs
name_model_save = "CRNN_GRU" #Name of the saving
model_trained = model_CRNN_GRU # choice of the model to train

dataset_train = dataset_train #Choice of the training dataset
#dataset_validation = dataset_validation #Choice of the validation dataset
callback = [early_stopping]
#---------------------------------------------------
from google.colab import drive
import pickle
##################################
# Training & saving of the model #
##################################
def model_training_saving(model_trained,dataset_train,epochs, dataset_validation,callbacks,save_model_bol,name_model_save):
  #Training of model and saving
  print("--> Training:\n")
  training_history=model_trained.fit(dataset_train,epochs=epochs, validation_data=dataset_validation,callbacks=callbacks)
  print("\nTraining done !\n")
  # Saving of the model
  print("\n--> Saving:\n")
  try:
    save_model(save_model_bol, model_trained,name_model_save,training_history)
  except:
    print("Saving not succeed")

  return training_history, model_trained

#--------------------------------------------------------------------------

print("\nTraining of the CRNN_LSTM model:\n")
training_history_CRNN_LSTM, model_CRNN_LSTM = model_training_saving(model_trained = model_CRNN_LSTM,
                                                                    dataset_train = dataset_train,
                                                                    epochs = 50,
                                                                    dataset_validation= dataset_validation,
                                                                    callbacks = callback,
                                                                    save_model_bol = True,
                                                                    name_model_save = "CRNN_LSTM")

print("\nTraining of the CRNN_GRU model:\n")
training_history_CRNN_GRU, model_CRNN_GRU = model_training_saving(model_trained = model_CRNN_GRU,
                                                                  dataset_train= dataset_train,
                                                                  epochs= 50,
                                                                  dataset_validation= dataset_validation,
                                                                  callbacks= callback,
                                                                  save_model_bol= True,
                                                                  name_model_save="CRNN_GRU")
# Out:
# Training of the CRNN_LSTM model:
#
# --> Training:
#
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-4f99c7e7d8db> in <module>
#      42                                                                     callbacks = callback,
#      43                                                                     save_model_bol = True,
# ---> 44                                                                     name_model_save = "CRNN_LSTM")
#      45
#      46 print("\nTraining of the CRNN_GRU model:\n")
#
# <ipython-input-67-4f99c7e7d8db> in model_training_saving(model_trained, dataset_train, epochs, dataset_validation, callbacks, save_model_bol, name_model_save)
#      22   #Training of model and saving
#      23   print("--> Training:\n")
# ---> 24   training_history=model_trained.fit(dataset_train,epochs=epochs, validation_data=dataset_validation,callbacks=callbacks)
#      25   print("\nTraining done !\n")
#      26   # Saving of the model
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
print("\nTraining of the CRNN_GRU model:\n")
training_history_CRNN_GRU, model_CRNN_GRU = model_training_saving(model_trained = model_CRNN_GRU,
                                                                  dataset_train= dataset_train,
                                                                  epochs= 50,
                                                                  dataset_validation= dataset_validation,
                                                                  callbacks= callback,
                                                                  save_model_bol= False,
                                                                  name_model_save="CRNN_GRU")
# Out:
# Training of the CRNN_GRU model:
#
# --> Training:
#
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-52907d1b6640> in <module>
#       6                                                                   callbacks= callback,
#       7                                                                   save_model_bol= False,
# ----> 8                                                                   name_model_save="CRNN_GRU")
#
# <ipython-input-67-4f99c7e7d8db> in model_training_saving(model_trained, dataset_train, epochs, dataset_validation, callbacks, save_model_bol, name_model_save)
#      22   #Training of model and saving
#      23   print("--> Training:\n")
# ---> 24   training_history=model_trained.fit(dataset_train,epochs=epochs, validation_data=dataset_validation,callbacks=callbacks)
#      25   print("\nTraining done !\n")
#      26   # Saving of the model
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
# --> 956         raise ValueError("Creating variables on a non-first call to a function"
#     957                          " decorated with tf.function.")
#     958       return results
#
# ValueError: Creating variables on a non-first call to a function decorated with tf.function.

# %%
#@title Display of the training history

#############
# Variables #
#############

history_CRNN_GRU= training_history_CRNN_GRU.history
history_CRNN_LSTM=training_history_CRNN_LSTM.history
#-------------------------------------
################################
# Display of Training history  #
################################

def display_of_training_history(history,title=None):
  if title ==None:
    title= "Training history"
  
  

  plt.plot(history["loss"],label="Loss")
  plt.plot(history["val_loss"],label="Val_loss")

  
  plt.legend()
  plt.xticks(np.arange(0,len(history["loss"]),1));

  plt.xlim([0,len(history["loss"])-1]);
  plt.grid()
  plt.xlabel("Epochs")
  plt.ylabel("Loss value");
  plt.title(title);

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
display_of_training_history(history_CRNN_LSTM,"CRNN_LSTM training history")
plt.subplot(1,2,2)
display_of_training_history(history_CRNN_GRU,"CRNN_GRU training history")

# %% [markdown]
# #Prediction & Evaluation

# %% [markdown]
# ## Predictions

# %%
#@title GreedyDecoder, Prediction, Orthographique Correction functions

from textblob import TextBlob

#####################################################
# Definition of decode function and Greedy decoder  #
#####################################################

def decode_codes(codes):
    table = tf.lookup.StaticHashTable(
        tf.lookup.KeyValueTensorInitializer(
            np.arange(len(charList)),
            charList,
            key_dtype=tf.int32
        ),
        '',
        name='id2char'
    )
    return table.lookup(codes)

def greedy_decoder(logits):
    # ctc beam search decoder
    predicted_codes, _ = tf.nn.ctc_greedy_decoder(
        # shape of tensor [max_time x batch_size x num_classes]
        tf.transpose(logits, (1, 0, 2)),
        [logits.shape[1]]*logits.shape[0]
    )

    # convert to int32
    codes = tf.cast(predicted_codes[0], tf.int32)

    # Decode the index of caracter
    text = decode_codes(codes)

    # Convert a SparseTensor to string
    text = tf.sparse.to_dense(text).numpy().astype(str)

    return list(map(lambda x: ''.join(x), text))

#--------------------------------------------------------

#################################################
# Function: Prediction and Decoding of dataset  #
#################################################

def predictions_decode(dataset,model):
  y_pred=[]
  y_true=[]
  for X_t,y_t in dataset:
    y_pred.append(greedy_decoder(model(X_t)))
    y_true.append(y_t)


  results=list(zip(np.array(y_true).flatten(),np.array(y_pred).flatten(),))
  return y_true,y_pred,results

#---------------------------------------------------------------

###################################
# Function: Prediction correction #
###################################

def correct_word(x):
  return TextBlob(x).correct()

def correct_prediction(y_true,y_pred):

  y_pred_corr = map(correct_word,np.array(y_pred).flatten())
  results_corrected=list(zip(np.array(y_true).flatten(),y_pred_corr,))

  return y_pred_corr, results_corrected

# %%
#############
# Variables #
#############

model = model_CRNN_LSTM
dataset_test = dataset_test

#--------------------------------------------------------
######################################################
# Decoded predictions and Orthographique corrections #
######################################################

y_true,y_pred, results = predictions_decode(dataset_test,model)

y_pred_corr , results_corrected = correct_prediction(y_true,y_pred)

# %% [markdown]
# ##Evaluation

# %%
#@title Word accuracy function & Analysis of model
##########################
# Function Word accuracy #
##########################
import difflib

def word_accuracy(results,verbose,name_results=None):

  score=[]
  for words in results: # Calculation of the percentage of letters accuracy for each word between transcription and prediction
    score.append(difflib.SequenceMatcher(None,words[0].decode("utf-8"),words[1]).ratio())
  
  if verbose:
    print("The average accuracy for our words prediction,",name_results,", is: ",np.mean(score),
      "\n\n--------------------------------------------------------------------\n")
    
  return score

#----------------------------------------

# %%
#@title Model analysis function



  #-----------------------------------------------------------------------------------------------------------------------------

def display_word_accuracy(results,results_name,results_corrected,results_corrected_name,verbose):
  ####################################
  # Evaluation of the words accuracy #
  ####################################

  score = word_accuracy(results, verbose, results_name)
  score_corrected = word_accuracy(results_corrected,verbose, results_corrected_name)

  #-----------------------------------------------------

  ##################################################
  # Display of the word accuracy (WA) repartition #
  ##################################################

  plt.figure(figsize=(8,8))
  # evaluation of the histogram
  values, base = np.histogram(score, bins=100)
  values_corrected, base_corrected = np.histogram(score_corrected, bins=100)
  #evaluation the cumulative
  cumulative = np.cumsum(values)
  cumulative_corrected = np.cumsum(values_corrected)
  # plot the cumulative function
  plt.plot(base[:-1], cumulative/cumulative[-1], c='blue',label="Prediction")
  plt.plot(base[:-1], cumulative_corrected/cumulative_corrected[-1], c='red',label="Prediction with autocorrect")


  plt.title("Repartition of predictions accuracy (WA)")
  plt.xlabel("Accuracy")
  plt.ylabel("Predictions % below the accuracy")
  plt.xticks(np.arange(0,1.1,0.1))
  plt.yticks(np.arange(0.1,1.1,0.1))
  plt.xlim([0,1])
  plt.ylim([0,1])
  plt.grid()
  plt.legend(loc="upper left")
  plt.show();

  ar_res = np.array(results)
  ar_score = np.array(score)

  ar_res_cor = np.array(results_corrected)
  ar_score_cor = np.array(score_corrected)

  print("According to the graph we have for the basic predictions approximatly:\n",
        "-",np.round((len(ar_res[(ar_score <= 0.1)])/len(ar_res))*100), "% predictions at <10% of accuracy\n",
        "-",np.round((len(ar_res[(0.1 < ar_score) & (ar_score <= 0.5)])/len(ar_res))*100)  ,"% predictions between 10% - 50% of accuracy\n",
        "-",np.round((len(ar_res[(0.5 < ar_score) & (ar_score <= 0.99)])/len(ar_res))*100) ,"% predictions between 50%- 99% of accuracy\n",
        "-",np.round((len(ar_res[(0.99 < ar_score)])/len(ar_res))*100) ,"% predictions at 100% of accuracy")

  print("\n\nAccording to the graph we have for the autocorrect predictions approximatly:\n",
        "-",np.round((len(ar_res_cor[(ar_score_cor <= 0.1)])/len(ar_res_cor))*100), "% predictions at <10% of accuracy\n",
        "-",np.round((len(ar_res_cor[(0.1 < ar_score_cor) & (ar_score_cor <= 0.5)])/len(ar_res_cor))*100)  ,"% predictions between 10% - 50% of accuracy\n",
        "-",np.round((len(ar_res_cor[(0.5 < ar_score_cor) & (ar_score_cor <= 0.99)])/len(ar_res_cor))*100) ,"% predictions between 50%- 99% of accuracy\n",
        "-",np.round((len(ar_res_cor[(0.99 < ar_score_cor)])/len(ar_res_cor))*100) ,"% predictions at 100% of accuracy");



def model_analysis(model,dataset,results_name="raw",results_corrected_name="with autocorrect",verbose=True):
  y_true,y_pred, results = predictions_decode(dataset,model)

  y_pred_corr , results_corrected = correct_prediction(y_true,y_pred)

  results = results
  results_corrected = results_corrected

  display_word_accuracy(results,results_name,results_corrected,results_corrected_name,verbose)

# %%
model_analysis(model_CRNN_GRU,dataset_test)
# Out:
# The average accuracy for our words prediction, raw , is:  0.9461111050990112
#
# --------------------------------------------------------------------
#
# The average accuracy for our words prediction, with autocorrect , is:  0.9355631816621366
#
# --------------------------------------------------------------------
# According to the graph we have for the basic predictions approximatly:
#  - 2.0 % predictions at <10% of accuracy
#  - 2.0 % predictions between 10% - 50% of accuracy
#  - 15.0 % predictions between 50%- 99% of accuracy
#  - 82.0 % predictions at 100% of accuracy
#
#
# According to the graph we have for the autocorrect predictions approximatly:
#  - 2.0 % predictions at <10% of accuracy
#  - 3.0 % predictions between 10% - 50% of accuracy
#  - 10.0 % predictions between 50%- 99% of accuracy
#  - 84.0 % predictions at 100% of accuracy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:47: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
model_analysis(model_CRNN_LSTM,dataset_test)
# Out:
# The average accuracy for our words prediction, raw , is:  0.9537564333753693
#
# --------------------------------------------------------------------
#
# The average accuracy for our words prediction, with autocorrect , is:  0.9431950589175775
#
# --------------------------------------------------------------------
# According to the graph we have for the basic predictions approximatly:
#  - 2.0 % predictions at <10% of accuracy
#  - 1.0 % predictions between 10% - 50% of accuracy
#  - 13.0 % predictions between 50%- 99% of accuracy
#  - 84.0 % predictions at 100% of accuracy
#
#
# According to the graph we have for the autocorrect predictions approximatly:
#  - 2.0 % predictions at <10% of accuracy
#  - 2.0 % predictions between 10% - 50% of accuracy
#  - 10.0 % predictions between 50%- 99% of accuracy
#  - 86.0 % predictions at 100% of accuracy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:55: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
#@title Display of several failed predictions
#############
# Variables #
#############

results = results
score = score
#-------------------------------------------

########################################
# Display of several failed prediction #
########################################

np.array(results)[np.array(score) < 0.1][:10]

#-------------------------------------------

# %% [markdown]
# # Reading of one form using a model

# %%
#############
# Variables #
#############

form_id ="a01-020u"

#--------------------------------------------------------------------------
from pathlib import Path
import imghdr

##################################
#   Removal of unwanted Column   #
##################################

list_columns_to_remove=["segmentation_result","gray_level","x","y","pxw","pxh","grammatical_tag","number_components"]

form_df = word_txt[word_txt.segmentation_result == "ok"]\
          .drop(columns=list_columns_to_remove)

################################
# Selection of wanted form     #
################################

form_df = form_df[form_df.word_id.str.contains(form_id)]

#----------------------------------------------------

###############################
#    Removal of corrupt image #
###############################

print("df Length: ",len(form_df))
form_df["filepath"]=form_df.word_id.apply(img_path)
form_df=removal_of_corrupt_image(form_df)
print("df Length: ",len(form_df))
# Out:
# df Length:  68
# data/words/r06/r06-022/r06-022-03-05.png is not an image
# data/words/a01/a01-117/a01-117-05-02.png is not an image
# df Length:  68

# %%
#############
# Variables #
#############

model = model_CRNN_GRU
batch_size = 1
image_width=128
image_height=32
imgSize = (image_height, image_width)

#-----------------------------------

#########################################
# Creation of the train & test datasets #
#########################################

# Creation of dataset_train tensor and preprocessing of images
data_form = tf.data.Dataset.from_tensor_slices((form_df.filepath.values, form_df.transcription.values))
data_form = data_form\
                .map(lambda x, y : [preprocess(x, imgSize, dataAugmentation=True, scale=0.8, isthreshold=True), y])\
                .batch(batch_size, drop_remainder=True)

#-----------------------------------------------------------------------------

##############################
# Prediction using the model #
##############################

y_pred=[]
y_true=[]
for X_t,y_t in data_form:
  y_pred.append(greedy_decoder(model(X_t)))
  y_true.append(y_t.numpy()[0].decode("utf-8"))

results=list(zip(np.array(y_true).flatten(),np.array(y_pred).flatten(),))


y_pred=np.array(y_pred).flatten()
y_true=np.array(y_true).flatten()

pred_text=' '.join(y_pred)
true_text=' '.join(y_true)

print("\nTrue text:\n")
print(true_text)
print("\nPredicted text:\n")
print(pred_text)
print("\nCorrected predicted text:\n")
print(correct_word(pred_text))
# Out:
# True text:
#
# Mr. Macleod went on with the conference at Lancaster House despite the crisis which had blown up . He has now revealed his full plans to the Africans and Liberals attending . These plans do not give the Africans the overall majority they are seeking . African delegates are studying them today . The conference will meet to discuss the function of a proposed House of Chiefs .
#
# Predicted text:
#
# MR. Maclead went an with the conference at Lancaster House despite the arisis which had blown up . He has now revealed his full plans to the Africans and likeats attending . These olcuss do not give the Africans the overall mgjority they are seeking . African delegates oe studying them tody . The conference will meer to discuss the function of a puoposed House of Chiefs .
#
# Corrected predicted text:
#
# of. Maclead went an with the conference at Lancaster House despite the crisis which had blown up . He has now revealed his full plans to the Africans and likes attending . These occurs do not give the Africans the overall majority they are seeking . African delegates oe studying them body . The conference will meet to discuss the function of a proposed House of Chiefs .

# %% [markdown]
# # Segmentation of a Form to a list of words

# %% [markdown]
# ## Creation of the list of word images

# %%
#@title Mounting the drive (having the form images) and listing of the paths
from google.colab import drive
import tarfile
import os

formsAD_path = "./formsA-D/"

drive.mount("/drive")
list_tar=["lines","formsA-D"]
for name in list_tar:
  my_tar = tarfile.open("/drive/MyDrive/DataScience/OCR/"+name+".tgz")
  my_tar.extractall('./'+name) # specify which folder to extract to

my_tar.close()

dir_list=os.listdir(formsAD_path)
dir_list = list(map(lambda x :formsAD_path+x,dir_list))
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
#@title Functions to cut lines from form
import numpy as np
#img = np.sum(cv2.imread(formid),axis=2)[690:2700]
def black_white_img(formid):
  img = cv2.imread(formid)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)#[690:2700]

  (thresh, blackAndWhiteImage) = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
  return blackAndWhiteImage

def get_line_cut(img):
  img_col = np.sum(img,axis=1)
  list_lines= []

  for i, value in enumerate(img_col):
    if value > img_col.mean():
      list_lines.append(i)
  #list_lines.append(1e10)

  new_list_lines=[]
  temporary_list=[]
  last_line=list_lines[0]
  for line in list_lines:
    if line <= last_line+15:
      
      temporary_list.append(line)
      last_line = line
    
    else:
      
      new_list_lines.append(int(np.mean(temporary_list)))
      temporary_list=[line]
      last_line = line

  temp_list=[]
  for i in range(len(new_list_lines)-1):
    temp_list.append(new_list_lines[i+1]-new_list_lines[i])

  new_list_lines.append(new_list_lines[-1]+int(np.mean(temp_list)))
  return new_list_lines

def get_lines(img):
  max_line=[]
  for line in (img==0):
    compteur_list=[]
    compteur=0
    
    for col in line:
      
      if col == True:
        compteur = compteur+1
      else:
        compteur_list.append(compteur)
        compteur=0

    compteur_list.append(compteur)
    
    max_line.append(np.max(compteur_list))
  max_line=np.array(max_line)

  return max_line

# %%
#@title Random selection and display of the formID
formid = dir_list[np.random.randint(0,len(dir_list))]
img_color=cv2.imread(formid)
img_bw=black_white_img(formid)

list_lines=get_line_cut(img_bw)

plt.figure(figsize=(10,10))

plt.imshow(img_bw,cmap="gray")
plt.title(formid)
# Out:
# Text(0.5, 1.0, './formsA-D/c02-026.png')

# %%
#@title Creation and display of the list of lines from the form
max_line=get_lines(img_bw)
max_line=max_line>max_line.max()/2
x_bot=np.argsort(max_line[2000:])[-1]+2000-10
x_top=np.argsort(max_line[500:1000])[-1]+500+10

only_text_img_color = img_color[x_top:x_bot,:,:]
only_text_img_bw = img_bw[x_top:x_bot,:]

lines=get_line_cut(only_text_img_bw)

list_img_lines=[]
for i in range(len(lines)-1):
  list_img_lines.append(only_text_img_color[lines[i]:lines[i+1],:,:])

for j in range(len(list_img_lines)):
  plt.subplot(len(list_img_lines),1,j+1)
  plt.axis('off')
  plt.imshow(list_img_lines[j],cmap="gray")

# %%
#@title Functions for word cutting
import cv2
import numpy as np

def image_contour(img):
    src_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    src_gray = cv2.blur(src_gray, (3,3))
    threshold=100
    canny_output = cv2.Canny(src_gray, threshold, threshold * 2)
    
    return src_gray,cv2.findContours(canny_output, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

    
def image_with_contours(img,contours=None):
    if contours==None:
        img, (contours,hierarchy) = image_contour(img)
    
    else:
        img = img[...,-1].astype(np.uint8)*255

    image_copy = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    plt.figure(figsize=(10,15))
    return cv2.drawContours(image=image_copy, 
                                contours=contours, 
                                contourIdx=-1, 
                                color=(0, 255, 0), 
                                thickness=4, 
                                lineType=cv2.LINE_AA);

def display_contour_box(img,contours=None):
    
    if contours==None:
      image_copy,(contours,hierarchy) = image_contour(img)
    
    else:
      src_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
      image_copy = cv2.blur(src_gray, (3,3))

    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        cv2.rectangle(image_copy, (x, y), (x + w, y + h), (36,255,12), 2)

    plt.figure(figsize=(20,30))
    plt.imshow(image_copy.astype(int))
    plt.xticks([])
    plt.yticks([]);


def create_new_contours(contours,xmax,ymax):
  list_of_exempt=[]
  new_contours=[]
  for i,c1 in enumerate(contours):
    if i in list_of_exempt:
      
      pass
    
    else:
      list_of_exempt.append(i)
      for j,c2 in enumerate(contours):
        if j in list_of_exempt:
          pass
        
        else:
          rec1=cv2.boundingRect(c1)
          rec2=cv2.boundingRect(c2)
          ctot=np.vstack([c1,c2])
          rectot=cv2.boundingRect(ctot)

          rec1=np.array(rec1)
          rec2=np.array(rec2)
          rectot=np.array(rectot)

          y_dist=rectot[3]-(rec1[3]+rec2[3])
          x_dist=rectot[2]-(rec1[2]+rec2[2])
          y_start_dist=np.abs(rec1[1]-rec2[1])

          if y_dist < ymax and x_dist<xmax:
            
            c1=ctot
            list_of_exempt.append(j)

       
      new_contours.append(c1)

  return new_contours

def contours_sorting(contours):
  list_x=[]
  for i,c in enumerate(contours):
    x, y, w, h = cv2.boundingRect(c)
    list_x.append([i,x])
  list_x= np.array(list_x)
  list_x=list_x[list_x[:, 1].argsort()]

  temp_contours=[]

  for val in list_x:
    i = val[0]
    temp_contours.append(mycontours[i])
  return temp_contours

# %%
#@title Segmentation of the lines and Creation of the list of word image from the form
def get_contour_image(img,c):
  x, y, w, h = cv2.boundingRect(c)
  return img[y:y+h,x:x+w]

list_words_img=[]

for img_line in list_img_lines:

  gray, (contours,hierarchy) = image_contour(img_line)
  import numpy as np
  mycontours=contours
  for l in range(10):
    #print("Iteration:",l)
    mycontours=create_new_contours(mycontours,25,100)

  mycontours = contours_sorting(mycontours)


  for c in mycontours:
    list_words_img.append(get_contour_image(img_line,c))


#display_contour_box(img_line,mycontours)

# %%
#@title Saving of the word images, listing of the paths and sorting of the list 
from PIL import Image
import os

directory_path="./formTest/"

try:
    os.mkdir(directory_path)
except OSError as error:
   pass 

for i, word_img in enumerate(list_words_img):
  im = Image.fromarray(word_img)
  im.save(directory_path+str(i)+".png")

dir_list=os.listdir(directory_path)
dir_list = list(map(lambda x :directory_path+x,dir_list))

#######################
# Sorting of the list #
#######################

import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]


dir_list.sort(key=natural_keys)

# %% [markdown]
# ##Prediction

# %%
#############
# Variables #
#############

model = model_CRNN_GRU
batch_size = 1
image_width=128
image_height=32
imgSize = (image_height, image_width)
form_id =formid.split("/")[-1].split(".")[0]

#--------------------------------------------------------------------------
from pathlib import Path
import imghdr

################################################################
#   Creation of the transcription linked to the form studied   #
################################################################

list_columns_to_remove=["segmentation_result","gray_level","x","y","pxw","pxh","grammatical_tag","number_components"]

form_df = word_txt[word_txt.segmentation_result == "ok"]\
          .drop(columns=list_columns_to_remove)

form_df = form_df[form_df.word_id.str.contains(form_id)]
true_text=form_df.transcription.apply(lambda x: x+" ").sum()

#---------------------------------------------------------------

#########################################
# Creation of the train & test datasets #
#########################################

# Creation of dataset_train tensor and preprocessing of images
data_form = tf.data.Dataset.from_tensor_slices((dir_list, range(len(list_words_img))))
data_form = data_form\
                .map(lambda x, y : [preprocess(x, imgSize, dataAugmentation=True, scale=0.8, isthreshold=True), y])\
                .batch(batch_size, drop_remainder=True)

#-----------------------------------------------------------------------------

##############################
# Prediction using the model #
##############################

y_pred=[]
y_true=[]
for X_t,y_t in data_form:
  y_pred.append(greedy_decoder(model(X_t)))
  y_true.append(y_t)

results=list(zip(np.array(y_true).flatten(),np.array(y_pred).flatten(),))

y_pred=np.array(y_pred).flatten()
y_true=np.array(y_true).flatten()

pred_text=' '.join(y_pred)
true_text=true_text

print("\nTrue text:\n")
print(true_text)
print("\nPredicted text:\n")
print(pred_text)
print("\nCorrected predicted text:\n")
print(correct_sentence(pred_text))
# Out:
# True text:
#
# A summary of the story can give almost tells his story best in the faces of his crowds , recording every wrinkle and drop of sweat with brutal honesty , building up to a tremendous climax in the island orgy . the wildly flapping white sails slashed by the glaring beacon of a lighthouse .
#
# Predicted text:
#
# , A summiay of the sttry em give eluasit , inodiceation of the icape Wimki's atitny . Hhe ! Hlls his shry best in the faces of wn cioudsy ! recviding ewwry wrinkle amd drep of sweat . ! with Drtal homnty , builtdhing up to a , tremendous clmenx in tle islemd oxgd . ! there , the ganst arrive in puest alike joudere , , the widly thapping wite jaike slanshed by ! the glaring beacon of a Cghthioules .
#
# Corrected predicted text:
#
# , A summary of the story em give eluasit , indication of the cape Mimi's tiny . The ! Ills his shy best in the faces of in clouds ! receiving every wrinkle and deep of sweat . ! with Real county , building up to a , tremendous client in the island old . ! there , the canst arrive in guest alike louder , , the widely tapping with jake slashed by ! the glaring beacon of a Cghthioules .
